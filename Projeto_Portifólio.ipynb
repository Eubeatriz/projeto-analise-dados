# %% [markdown]
# <a href="https://colab.research.google.com/github/Eubeatriz/projeto-analise-dados/blob/main/Projeto_Portif%C3%B3lio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Gerar uma lista com 10 números aleatórios entre 1 e 100
dados = [random.randint(1, 100) for _ in range(10)]

# Exibir a lista gerada
print("Lista de dados", dados)

# Plotar os dados
plt.plot(dados, marker='o')  # marcador em cada ponto para melhor visualização
plt.title("Gráfico de Números Aleatórios")  # Correção: plt.title, não plt.plt.title
plt.xlabel("Índice")
plt.ylabel("Valor")
plt.grid(True)
plt.show()
# Out:
# Lista de dados [24, 54, 8, 12, 35, 22, 28, 35, 71, 79]

# %%
# Out:
#   File "/tmp/ipython-input-2-3130813171.py", line 1
#     print (!Hello, Data Girls!)
#            ^
# SyntaxError: invalid syntax
